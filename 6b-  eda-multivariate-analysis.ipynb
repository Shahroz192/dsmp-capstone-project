# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# %%
df.head()
# Out:
#   property_type               society      sector  price  price_per_sqft  \
# 0          flat        apex our homes  sector 37c   0.33          3567.0
# 1          flat  shree vardhman flora   sector 90   0.90          4615.0
# 2          flat  radhakrishna society   sector 23   0.55          5000.0
# 3         house           independent   sector 28   1.39         11583.0
# 4          flat    microtek greenburg   sector 86   1.65          8707.0
#
#      area                                       areaWithType  bedRoom  \
# 0   925.0  Super Built up area 925(85.94 sq.m.)Built Up a...        2
# 1  1950.0             Super Built up area 1950(181.16 sq.m.)        3
# 2  1100.0             Super Built up area 1100(102.19 sq.m.)        2
# 3  1200.0  Plot area 540(50.17 sq.m.)Built Up area: 1450 ...        2
# 4  1895.0             Super Built up area 1895(176.05 sq.m.)        3
#
#    bathroom balcony  floorNum      facing   agePossession  \
# 0         2       1       3.0        West  Relatively New
# 1         4       3       4.0  South-West  Relatively New
# 2         2       1       1.0        West  Moderately Old
# 3         2       1       3.0  North-East    Old Property
# 4         4       3       8.0  North-West  Relatively New
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0                925.0          850.0        800.0           0             0
# 1               1950.0            NaN          NaN           0             1
# 2               1100.0            NaN          NaN           0             0
# 3                  NaN         1450.0       1200.0           0             0
# 4               1895.0            NaN          NaN           0             1
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                1           158
# 1           0           0       0                0           165
# 2           0           0       0                1            29
# 3           1           0       0                0            37
# 4           0           0       0                0           124

# %% [markdown]
# ### property_type vs price

# %%
sns.barplot(x=df['property_type'], y=df['price'], estimator=np.median)
# Out:
# c:\python\Lib\site-packages\numpy\lib\nanfunctions.py:1559: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a,
# <Axes: xlabel='property_type', ylabel='price'>

# %%
sns.boxplot(x=df['property_type'], y=df['price'])
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %% [markdown]
# ### property_type vs area

# %%
sns.barplot(x=df['property_type'], y=df['built_up_area'], estimator=np.median)
# Out:
# c:\python\Lib\site-packages\numpy\lib\nanfunctions.py:1559: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a,
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
sns.boxplot(x=df['property_type'], y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
# removing that crazy outlier
df = df[df['built_up_area'] != 737147]

# %%
sns.boxplot(x=df['property_type'], y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %% [markdown]
# ### property_type vs price_per_sqft

# %%
sns.barplot(x=df['property_type'], y=df['price_per_sqft'], estimator=np.median)
# Out:
# c:\python\Lib\site-packages\numpy\lib\nanfunctions.py:1559: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a,
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
sns.boxplot(x=df['property_type'], y=df['price_per_sqft'])
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
# check outliers
df[df['price_per_sqft'] > 100000][['property_type','society','sector','price','price_per_sqft','area','areaWithType', 'super_built_up_area', 'built_up_area', 'carpet_area']]
# Out:
#      property_type                      society     sector  price  \
# 89           house                dlf the grove  sector 54   5.70
# 446          house     unitech uniworld resorts  sector 33   9.50
# 562          house                  independent  sector 17   3.50
# 1019         house                  independent  sector 28   4.50
# 1063         house         eros rosewood villas  sector 49   2.75
# 1231         house       emaar the palm springs  sector 54  24.00
# 1336         house                  independent  sector 54   3.75
# 1370         house                   ardee city  sector 52   5.50
# 1662         house                  independent  sector 23   2.80
# 1679         house                  independent  sector 55   1.45
# 1836         house               uppal southend  sector 49   6.75
# 1846          flat           ambience caitriona  sector 24  14.00
# 1911         house  unitech nirvana birch court  sector 50   7.10
# 2008         house         bhim nagar, sector 6   sector 6   0.85
# 2135         house            vatika india next  sector 82   7.00
# 2191         house       dlf city plots phase 2  sector 25  10.50
# 2276         house       dlf city plots phase 2  sector 25  10.00
# 2305         house          huda plot sector 38  sector 38   4.30
# 2341         house                  independent  sector 57   8.00
# 2343         house                  independent  sector 38   8.00
# 2452         house                  independent  sector 24  10.00
# 2584         house     unitech uniworld resorts  sector 33  10.00
# 2683         house                    rk excelo  sector 12   0.60
# 2701         house                  independent  sector 12   3.50
# 2927         house                  independent   sector 4   0.60
# 3242         house                  independent  sector 12   6.00
# 3412         house                        ansal  sector 43   1.85
# 3522         house           vipul tatvam villa  sector 48   7.25
# 3696         house       unitech deerwood chase  sector 50   8.45
#
#       price_per_sqft   area  \
# 89          211111.0  270.0
# 446         173992.0  546.0
# 562         218750.0  160.0
# 1019        125000.0  360.0
# 1063        178571.0  154.0
# 1231        600000.0  400.0
# 1336        234375.0  160.0
# 1370        183333.0  300.0
# 1662        161849.0  173.0
# 1679        241666.0   60.0
# 1836        290948.0  232.0
# 1846        200000.0  700.0
# 1911        283333.0  251.0
# 2008        126865.0   67.0
# 2135        194444.0  360.0
# 2191        261194.0  402.0
# 2276        400000.0  250.0
# 2305        245398.0  175.0
# 2341        266666.0  300.0
# 2343        230547.0  347.0
# 2452        229885.0  435.0
# 2584        181818.0  550.0
# 2683        120000.0   50.0
# 2701        133079.0  263.0
# 2927        105263.0   57.0
# 3242        315789.0  190.0
# 3412        308333.0   60.0
# 3522        201388.0  360.0
# 3696        235376.0  359.0
#
#                                            areaWithType  super_built_up_area  \
# 89                     Built Up area: 270 (25.08 sq.m.)                  NaN
# 446                          Plot area 546(50.73 sq.m.)                  NaN
# 562                    Built Up area: 160 (14.86 sq.m.)                  NaN
# 1019                   Built Up area: 360 (33.45 sq.m.)                  NaN
# 1063  Plot area 154(14.31 sq.m.)Carpet area: 1650 sq...                  NaN
# 1231                         Plot area 400(37.16 sq.m.)                  NaN
# 1336                         Plot area 160(14.86 sq.m.)                  NaN
# 1370                         Plot area 300(27.87 sq.m.)                  NaN
# 1662  Plot area 173(16.07 sq.m.)Built Up area: 160 s...                  NaN
# 1679                           Plot area 60(5.57 sq.m.)                  NaN
# 1836                         Plot area 232(21.55 sq.m.)                  NaN
# 1846                   Built Up area: 700 (65.03 sq.m.)                  NaN
# 1911                          Plot area 240(22.3 sq.m.)                  NaN
# 2008                           Plot area 67(6.22 sq.m.)                  NaN
# 2135  Plot area 360(33.45 sq.m.)Built Up area: 3900 ...                  NaN
# 2191                         Plot area 402(37.35 sq.m.)                  NaN
# 2276                         Plot area 250(23.23 sq.m.)                  NaN
# 2305  Plot area 163(15.14 sq.m.)Built Up area: 145 s...                  NaN
# 2341                         Plot area 300(27.87 sq.m.)                  NaN
# 2343  Built Up area: 347 (32.24 sq.m.)Carpet area: 2...                  NaN
# 2452                     Carpet area: 435 (40.41 sq.m.)                  NaN
# 2584                          Plot area 550(51.1 sq.m.)                  NaN
# 2683  Plot area 50(4.65 sq.m.)Built Up area: 30 sq.f...                  NaN
# 2701  Plot area 263(24.43 sq.m.)Built Up area: 4800 ...                  NaN
# 2927                            Plot area 57(5.3 sq.m.)                  NaN
# 3242  Plot area 190(17.65 sq.m.)Carpet area: 1600 sq...                  NaN
# 3412                           Plot area 60(5.57 sq.m.)                  NaN
# 3522                         Plot area 360(33.45 sq.m.)                  NaN
# 3696                         Plot area 359(33.35 sq.m.)                  NaN
#
#       built_up_area  carpet_area
# 89            270.0          NaN
# 446           546.0          NaN
# 562           160.0          NaN
# 1019          360.0          NaN
# 1063            NaN       1650.0
# 1231          400.0          NaN
# 1336          160.0          NaN
# 1370          300.0          NaN
# 1662          160.0        150.0
# 1679           60.0          NaN
# 1836          232.0          NaN
# 1846          700.0          NaN
# 1911          240.0          NaN
# 2008           67.0          NaN
# 2135         3900.0       3743.0
# 2191          402.0          NaN
# 2276          250.0          NaN
# 2305          145.0          NaN
# 2341          300.0          NaN
# 2343          347.0        215.0
# 2452            NaN        435.0
# 2584          550.0          NaN
# 2683           30.0         15.0
# 2701         4800.0       4400.0
# 2927           57.0          NaN
# 3242            NaN       1600.0
# 3412           60.0          NaN
# 3522          360.0          NaN
# 3696          359.0          NaN

# %%
df.head()
# Out:
#   property_type               society      sector  price  price_per_sqft  \
# 0          flat        apex our homes  sector 37c   0.33          3567.0
# 1          flat  shree vardhman flora   sector 90   0.90          4615.0
# 2          flat  radhakrishna society   sector 23   0.55          5000.0
# 3         house           independent   sector 28   1.39         11583.0
# 4          flat    microtek greenburg   sector 86   1.65          8707.0
#
#      area                                       areaWithType  bedRoom  \
# 0   925.0  Super Built up area 925(85.94 sq.m.)Built Up a...        2
# 1  1950.0             Super Built up area 1950(181.16 sq.m.)        3
# 2  1100.0             Super Built up area 1100(102.19 sq.m.)        2
# 3  1200.0  Plot area 540(50.17 sq.m.)Built Up area: 1450 ...        2
# 4  1895.0             Super Built up area 1895(176.05 sq.m.)        3
#
#    bathroom balcony  floorNum      facing   agePossession  \
# 0         2       1       3.0        West  Relatively New
# 1         4       3       4.0  South-West  Relatively New
# 2         2       1       1.0        West  Moderately Old
# 3         2       1       3.0  North-East    Old Property
# 4         4       3       8.0  North-West  Relatively New
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0                925.0          850.0        800.0           0             0
# 1               1950.0            NaN          NaN           0             1
# 2               1100.0            NaN          NaN           0             0
# 3                  NaN         1450.0       1200.0           0             0
# 4               1895.0            NaN          NaN           0             1
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                1           158
# 1           0           0       0                0           165
# 2           0           0       0                1            29
# 3           1           0       0                0            37
# 4           0           0       0                0           124

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['bedRoom']))
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
# checking outliers
df[df['bedRoom'] >= 10]
# Out:
#      property_type                    society     sector  price  \
# 98           house               malibu towne  sector 47   8.50
# 185          house  ganpati heights apartment  sector 13   1.25
# 195          house             uppal southend  sector 49   6.75
# 233          house           dlf city phase 1  sector 26   9.25
# 313          house                independent  sector 11   1.35
# ...            ...                        ...        ...    ...
# 3481         house                independent  sector 28    NaN
# 3484         house                independent  sector 41   4.25
# 3725         house                independent  sector 43   7.50
# 3761         house                independent  sector 56  12.39
# 3787         house                independent  sector 11   4.50
#
#       price_per_sqft     area  \
# 98           53125.0   1600.0
# 185            151.0  82781.0
# 195          31915.0   2115.0
# 233          47803.0   1935.0
# 313           3857.0   3500.0
# ...              ...      ...
# 3481             NaN      NaN
# 3484         26235.0   1620.0
# 3725         38760.0   1935.0
# 3761         45889.0   2700.0
# 3787         25000.0   1800.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 98                   Built Up area: 1600 (148.64 sq.m.)       12        12
# 185                        Plot area 115(7692.86 sq.m.)       10         6
# 195                         Plot area 235(196.49 sq.m.)       12        12
# 233   Plot area 1935(179.77 sq.m.)Built Up area: 700...       12        12
# 313                        Plot area 3500(325.16 sq.m.)       10         6
# ...                                                 ...      ...       ...
# 3481                        Plot area 270(225.75 sq.m.)       16        16
# 3484                         Plot area 180(150.5 sq.m.)       10         9
# 3725                        Plot area 215(179.77 sq.m.)       12        12
# 3761                        Plot area 300(250.84 sq.m.)       16        18
# 3787                        Plot area 200(167.23 sq.m.)       16        16
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 98        3+       4.0       North    New Property                  NaN
# 185        2       3.0  South-East    Old Property                  NaN
# 195       3+       3.0        West  Moderately Old                  NaN
# 233       3+       4.0  North-East    New Property                  NaN
# 313       3+       3.0         NaN    Old Property                  NaN
# ...      ...       ...         ...             ...                  ...
# 3481      3+       4.0  North-West    New Property                  NaN
# 3484      3+       4.0       North  Moderately Old                  NaN
# 3725      3+       4.0        East    New Property                  NaN
# 3761      3+       4.0  North-East    New Property                  NaN
# 3787      3+       4.0       South  Relatively New                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 98           1600.0          NaN           0             0           0
# 185           115.0          NaN           0             0           0
# 195          2115.0          NaN           0             0           0
# 233          7000.0          NaN           0             1           0
# 313          3500.0          NaN           0             0           0
# ...             ...          ...         ...           ...         ...
# 3481          270.0          NaN           1             1           0
# 3484         1620.0          NaN           1             1           0
# 3725         1935.0          NaN           1             1           1
# 3761         2700.0          NaN           0             1           0
# 3787         1800.0          NaN           0             0           0
#
#       pooja room  others  furnishing_type  luxury_score
# 98             0       0                1            99
# 185            0       1                0             7
# 195            0       1                0            49
# 233            1       0                1            43
# 313            0       0                0             0
# ...          ...     ...              ...           ...
# 3481           1       1                0            41
# 3484           0       0                1            36
# 3725           1       0                1            72
# 3761           1       0                1            49
# 3787           0       0                1            20
#
# [72 rows x 23 columns]

# %%
sns.barplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
sns.boxplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
# checking for outliers
df[(df['property_type'] == 'house') & (df['floorNum'] > 10)]
# Out:
#      property_type                  society      sector  price  \
# 324          house   vatika the seven lamps   sector 82   1.60
# 801          house              independent   sector 92   1.80
# 841          house         suncity township   sector 54   2.00
# 929          house              greenopolis   sector 89   0.70
# 942          house  indiabulls centrum park  sector 103   3.25
# 1062         house      ireo victory valley   sector 67   8.00
# 1473         house          godrej meridien  sector 106   5.60
# 2018         house              spaze privy   sector 72   3.09
# 2287         house        suncity avenue 76   sector 76   0.75
# 2717         house              spaze privy   sector 72   3.10
# 2867         house      satya the hermitage  sector 103   3.15
# 3225         house           dlf the arbour   sector 63   8.50
# 3469         house               ninex city   sector 76   1.75
# 3490         house           ats tourmaline  sector 109   1.87
#
#       price_per_sqft    area  \
# 324           6597.0  2425.0
# 801           7627.0  2360.0
# 841          30968.0   646.0
# 929           5397.0  1297.0
# 942           8125.0  4000.0
# 1062         22222.0  3600.0
# 1473         14000.0  4000.0
# 2018          6981.0  4426.0
# 2287         10067.0   745.0
# 2717          8486.0  3653.0
# 2867          6702.0  4700.0
# 3225         21519.0  3950.0
# 3469          6250.0  2800.0
# 3490          8697.0  2150.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 324                        Plot area 2425(225.29 sq.m.)        4         4
# 801                  Built Up area: 2360 (219.25 sq.m.)        4         5
# 841   Plot area 60Built Up area: 60 sq.m.Carpet area...        9         9
# 929                   Built Up area: 1297 (120.5 sq.m.)        2         2
# 942                        Plot area 4000(371.61 sq.m.)        4         3
# 1062                        Plot area 400(334.45 sq.m.)        6         7
# 1473                       Plot area 4000(371.61 sq.m.)        5         4
# 2018  Built Up area: 3653 (339.37 sq.m.)Carpet area:...        5         5
# 2287  Plot area 745(69.21 sq.m.)Built Up area: 745 s...        2         2
# 2717                       Plot area 3653(339.37 sq.m.)        5         5
# 2867                 Built Up area: 4700 (436.64 sq.m.)        4         5
# 3225                 Built Up area: 3950 (366.97 sq.m.)        4         4
# 3469                   Carpet area: 2800 (260.13 sq.m.)        4         4
# 3490                 Built Up area: 2150 (199.74 sq.m.)        3         4
#
#      balcony  floorNum      facing       agePossession  super_built_up_area  \
# 324       3+      16.0       North      Moderately Old                  NaN
# 801        0      13.0         NaN           Undefined                  NaN
# 841        3      11.0       North      Relatively New                  NaN
# 929        2      14.0  North-East           Undefined                  NaN
# 942       3+      20.0         NaN  Under Construction                  NaN
# 1062      3+      51.0  North-East      Moderately Old                  NaN
# 1473      3+      33.0  North-East        New Property                  NaN
# 2018      3+      14.0        East      Relatively New                  NaN
# 2287       2      11.0  North-East        New Property                  NaN
# 2717      3+      21.0         NaN      Relatively New                  NaN
# 2867       0      12.0        East           Undefined                  NaN
# 3225      3+      27.0         NaN           Undefined                  NaN
# 3469       0      14.0         NaN           Undefined                  NaN
# 3490       0      12.0         NaN           Undefined                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 324          2425.0          NaN           0             1           0
# 801          2360.0          NaN           0             0           0
# 841            60.0         59.0           0             1           0
# 929          1297.0          NaN           0             0           0
# 942          4000.0          NaN           0             0           0
# 1062         3600.0          NaN           1             1           0
# 1473         4000.0          NaN           1             1           1
# 2018         3653.0       2922.0           0             1           0
# 2287          745.0          NaN           0             0           0
# 2717         3653.0          NaN           0             0           0
# 2867         4700.0          NaN           0             0           0
# 3225         3950.0          NaN           0             0           0
# 3469            NaN       2800.0           0             0           0
# 3490         2150.0          NaN           0             0           0
#
#       pooja room  others  furnishing_type  luxury_score
# 324            0       0                0            94
# 801            0       0                0             0
# 841            0       0                2             7
# 929            0       0                0             0
# 942            0       0                0            51
# 1062           1       0                1            49
# 1473           1       0                0           151
# 2018           0       0                1            33
# 2287           0       0                0            40
# 2717           0       0                0             0
# 2867           0       0                0            61
# 3225           0       0                0            61
# 3469           0       0                0             0
# 3490           0       0                0             0

# %%
# conclusion houses(villa) but in appartments

# %%
df.head()
# Out:
#   property_type               society      sector  price  price_per_sqft  \
# 0          flat        apex our homes  sector 37c   0.33          3567.0
# 1          flat  shree vardhman flora   sector 90   0.90          4615.0
# 2          flat  radhakrishna society   sector 23   0.55          5000.0
# 3         house           independent   sector 28   1.39         11583.0
# 4          flat    microtek greenburg   sector 86   1.65          8707.0
#
#      area                                       areaWithType  bedRoom  \
# 0   925.0  Super Built up area 925(85.94 sq.m.)Built Up a...        2
# 1  1950.0             Super Built up area 1950(181.16 sq.m.)        3
# 2  1100.0             Super Built up area 1100(102.19 sq.m.)        2
# 3  1200.0  Plot area 540(50.17 sq.m.)Built Up area: 1450 ...        2
# 4  1895.0             Super Built up area 1895(176.05 sq.m.)        3
#
#    bathroom balcony  floorNum      facing   agePossession  \
# 0         2       1       3.0        West  Relatively New
# 1         4       3       4.0  South-West  Relatively New
# 2         2       1       1.0        West  Moderately Old
# 3         2       1       3.0  North-East    Old Property
# 4         4       3       8.0  North-West  Relatively New
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0                925.0          850.0        800.0           0             0
# 1               1950.0            NaN          NaN           0             1
# 2               1100.0            NaN          NaN           0             0
# 3                  NaN         1450.0       1200.0           0             0
# 4               1895.0            NaN          NaN           0             1
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                1           158
# 1           0           0       0                0           165
# 2           0           0       0                1            29
# 3           1           0       0                0            37
# 4           0           0       0                0           124

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['agePossession']))
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='agePossession',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
plt.figure(figsize=(15,4))
sns.heatmap(pd.pivot_table(df,index='property_type',columns='bedRoom',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['furnishing_type']))
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='furnishing_type',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.barplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
sns.boxplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
df.head()
# Out:
#   property_type               society      sector  price  price_per_sqft  \
# 0          flat        apex our homes  sector 37c   0.33          3567.0
# 1          flat  shree vardhman flora   sector 90   0.90          4615.0
# 2          flat  radhakrishna society   sector 23   0.55          5000.0
# 3         house           independent   sector 28   1.39         11583.0
# 4          flat    microtek greenburg   sector 86   1.65          8707.0
#
#      area                                       areaWithType  bedRoom  \
# 0   925.0  Super Built up area 925(85.94 sq.m.)Built Up a...        2
# 1  1950.0             Super Built up area 1950(181.16 sq.m.)        3
# 2  1100.0             Super Built up area 1100(102.19 sq.m.)        2
# 3  1200.0  Plot area 540(50.17 sq.m.)Built Up area: 1450 ...        2
# 4  1895.0             Super Built up area 1895(176.05 sq.m.)        3
#
#    bathroom balcony  floorNum      facing   agePossession  \
# 0         2       1       3.0        West  Relatively New
# 1         4       3       4.0  South-West  Relatively New
# 2         2       1       1.0        West  Moderately Old
# 3         2       1       3.0  North-East    Old Property
# 4         4       3       8.0  North-West  Relatively New
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0                925.0          850.0        800.0           0             0
# 1               1950.0            NaN          NaN           0             1
# 2               1100.0            NaN          NaN           0             0
# 3                  NaN         1450.0       1200.0           0             0
# 4               1895.0            NaN          NaN           0             1
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                1           158
# 1           0           0       0                0           165
# 2           0           0       0                1            29
# 3           1           0       0                0            37
# 4           0           0       0                0           124

# %%
# sector analysis
plt.figure(figsize=(15,6))
sns.heatmap(pd.crosstab(df['property_type'],df['sector'].sort_index()))
# Out:
# <Axes: xlabel='sector', ylabel='property_type'>

# %%
# sector analysis
import re
# Group by 'sector' and calculate the average price
avg_price_per_sector = df.groupby('sector')['price'].mean().reset_index()

# Function to extract sector numbers
def extract_sector_number(sector_name):
    match = re.search(r'\d+', sector_name)
    if match:
        return int(match.group())
    else:
        return float('inf')  # Return a large number for non-numbered sectors

avg_price_per_sector['sector_number'] = avg_price_per_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sector_sorted_by_sector = avg_price_per_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sector_sorted_by_sector.set_index('sector')[['price']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Average Price per Sector (Sorted by Sector Number)')
plt.xlabel('Average Price')
plt.ylabel('Sector')
plt.show()

# %%
avg_price_per_sqft_sector = df.groupby('sector')['price_per_sqft'].mean().reset_index()

avg_price_per_sqft_sector['sector_number'] = avg_price_per_sqft_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sqft_sector_sorted_by_sector = avg_price_per_sqft_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sqft_sector_sorted_by_sector.set_index('sector')[['price_per_sqft']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
luxury_score = df.groupby('sector')['luxury_score'].mean().reset_index()

luxury_score['sector_number'] = luxury_score['sector'].apply(extract_sector_number)

# Sort by sector number
luxury_score_sector = luxury_score.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(luxury_score_sector.set_index('sector')[['luxury_score']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 2          flat                pyramid elite   sector 86   0.46
# 3          flat       breez global hill view  sohna road   0.32
# 4          flat  bestech park view sanskruti   sector 92   1.60
#
#    price_per_sqft     area                                       areaWithType  \
# 0          7585.0   1081.0  Super Built up area 1081(100.43 sq.m.)Carpet a...
# 1          8600.0   1105.0                   Carpet area: 1103 (102.47 sq.m.)
# 2            79.0  58228.0                 Carpet area: 58141 (5401.48 sq.m.)
# 3          5470.0    585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...
# 4          8020.0   1995.0  Super Built up area 1995(185.34 sq.m.)Built Up...
#
#    bedRoom  bathroom balcony  floorNum      facing       agePossession  \
# 0        3         2       2       2.0         NaN        New Property
# 1        2         2       2       4.0         NaN        New Property
# 2        2         2       1       0.0         NaN  Under Construction
# 3        2         2       1      17.0         NaN        New Property
# 4        3         4      3+      10.0  North-West      Relatively New
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               1081.0            NaN        650.0           0             0
# 1                  NaN            NaN       1103.0           1             1
# 2                  NaN            NaN      58141.0           0             0
# 3                  NaN         1000.0        585.0           0             0
# 4               1995.0         1615.0       1476.0           0             1
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                2             8
# 1           0           0       0                2            38
# 2           0           0       0                2            15
# 3           0           0       0                2            49
# 4           0           0       1                0           174

# %% [markdown]
# ### price

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x=df[df['area']<10000]['area'],y=df['price'],hue=df['bedRoom'])
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x=df[df['area']<10000]['area'],y=df['price'],hue=df['agePossession'])
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x=df[df['area']<10000]['area'],y=df['price'],hue=df['furnishing_type'].astype('category'))
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
sns.barplot(x=df['bedRoom'],y=df['price'],estimator=np.median)
# Out:
# c:\python\Lib\site-packages\numpy\lib\nanfunctions.py:1559: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a,
# <Axes: xlabel='bedRoom', ylabel='price'>

# %%
sns.barplot(x=df['agePossession'],y=df['price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['agePossession'],y=df['area'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['furnishing_type'],y=df['price'],estimator=np.median)
# Out:
# c:\python\Lib\site-packages\numpy\lib\nanfunctions.py:1559: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a,
# <Axes: xlabel='furnishing_type', ylabel='price'>

# %%
sns.scatterplot(x=df['luxury_score'],y=df['price'])
# Out:
# <Axes: xlabel='luxury_score', ylabel='price'>

# %% [markdown]
# ### correlation

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.corr())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 2
#       1 plt.figure(figsize=(8,8))
# ----> 2 sns.heatmap(df.corr())
#
# File c:\python\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\python\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File c:\python\Lib\site-packages\pandas\core\internals\managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File c:\python\Lib\site-packages\pandas\core\internals\managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: 'flat'

# %%
df.corr()['price'].sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df.corr()['price'].sort_values(ascending=False)
#
# File c:\python\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\python\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File c:\python\Lib\site-packages\pandas\core\internals\managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File c:\python\Lib\site-packages\pandas\core\internals\managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: 'flat'

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 2          flat                pyramid elite   sector 86   0.46
# 3          flat       breez global hill view  sohna road   0.32
# 4          flat  bestech park view sanskruti   sector 92   1.60
#
#    price_per_sqft     area                                       areaWithType  \
# 0          7585.0   1081.0  Super Built up area 1081(100.43 sq.m.)Carpet a...
# 1          8600.0   1105.0                   Carpet area: 1103 (102.47 sq.m.)
# 2            79.0  58228.0                 Carpet area: 58141 (5401.48 sq.m.)
# 3          5470.0    585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...
# 4          8020.0   1995.0  Super Built up area 1995(185.34 sq.m.)Built Up...
#
#    bedRoom  bathroom balcony  floorNum      facing       agePossession  \
# 0        3         2       2       2.0         NaN        New Property
# 1        2         2       2       4.0         NaN        New Property
# 2        2         2       1       0.0         NaN  Under Construction
# 3        2         2       1      17.0         NaN        New Property
# 4        3         4      3+      10.0  North-West      Relatively New
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               1081.0            NaN        650.0           0             0
# 1                  NaN            NaN       1103.0           1             1
# 2                  NaN            NaN      58141.0           0             0
# 3                  NaN         1000.0        585.0           0             0
# 4               1995.0         1615.0       1476.0           0             1
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                2             8
# 1           0           0       0                2            38
# 2           0           0       0                2            15
# 3           0           0       0                2            49
# 4           0           0       1                0           174

# %%
sns.pairplot(df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 sns.pairplot(df)
#
# File c:\python\Lib\site-packages\seaborn\axisgrid.py:2174, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2171 if hue is not None:
#    2172     grid.add_legend()
# -> 2174 grid.tight_layout()
#    2176 return grid
#
# File c:\python\Lib\site-packages\seaborn\axisgrid.py:118, in Grid.tight_layout(self, *args, **kwargs)
#     116 if self._tight_layout_pad is not None:
#     117     kwargs.setdefault("pad", self._tight_layout_pad)
# --> 118 self._figure.tight_layout(*args, **kwargs)
#     119 return self
#
# File c:\python\Lib\site-packages\matplotlib\figure.py:3544, in Figure.tight_layout(self, pad, h_pad, w_pad, rect)
#    3542 previous_engine = self.get_layout_engine()
#    3543 self.set_layout_engine(engine)
# -> 3544 engine.execute(self)
#    3545 if not isinstance(previous_engine, TightLayoutEngine) \
#    3546         and previous_engine is not None:
#    3547     _api.warn_external('The figure layout has changed to tight')
#
# File c:\python\Lib\site-packages\matplotlib\layout_engine.py:184, in TightLayoutEngine.execute(self, fig)
#     182 renderer = fig._get_renderer()
#     183 with getattr(renderer, "_draw_disabled", nullcontext)():
# --> 184     kwargs = get_tight_layout_figure(
#     185         fig, fig.axes, get_subplotspec_list(fig.axes), renderer,
#     186         pad=info['pad'], h_pad=info['h_pad'], w_pad=info['w_pad'],
#     187         rect=info['rect'])
#     188 if kwargs:
#     189     fig.subplots_adjust(**kwargs)
#
# File c:\python\Lib\site-packages\matplotlib\_tight_layout.py:266, in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     261         return {}
#     262     span_pairs.append((
#     263         slice(ss.rowspan.start * div_row, ss.rowspan.stop * div_row),
#     264         slice(ss.colspan.start * div_col, ss.colspan.stop * div_col)))
# --> 266 kwargs = _auto_adjust_subplotpars(fig, renderer,
#     267                                   shape=(max_nrows, max_ncols),
#     268                                   span_pairs=span_pairs,
#     269                                   subplot_list=subplot_list,
#     270                                   ax_bbox_list=ax_bbox_list,
#     271                                   pad=pad, h_pad=h_pad, w_pad=w_pad)
#     273 # kwargs can be none if tight_layout fails...
#     274 if rect is not None and kwargs is not None:
#     275     # if rect is given, the whole subplots area (including
#     276     # labels) will fit into the rect instead of the
#    (...)
#     280     # auto_adjust_subplotpars twice, where the second run
#     281     # with adjusted rect parameters.
#
# File c:\python\Lib\site-packages\matplotlib\_tight_layout.py:82, in _auto_adjust_subplotpars(fig, renderer, shape, span_pairs, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#      80 for ax in subplots:
#      81     if ax.get_visible():
# ---> 82         bb += [martist._get_tightbbox_for_layout_only(ax, renderer)]
#      84 tight_bbox_raw = Bbox.union(bb)
#      85 tight_bbox = fig.transFigure.inverted().transform_bbox(tight_bbox_raw)
#
# File c:\python\Lib\site-packages\matplotlib\artist.py:1415, in _get_tightbbox_for_layout_only(obj, *args, **kwargs)
#    1409 """
#    1410 Matplotlib's `.Axes.get_tightbbox` and `.Axis.get_tightbbox` support a
#    1411 *for_layout_only* kwarg; this helper tries to use the kwarg but skips it
#    1412 when encountering third-party subclasses that do not support it.
#    1413 """
#    1414 try:
# -> 1415     return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#    1416 except TypeError:
#    1417     return obj.get_tightbbox(*args, **kwargs)
#
# File c:\python\Lib\site-packages\matplotlib\axes\_base.py:4385, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4383 for axis in self._axis_map.values():
#    4384     if self.axison and axis.get_visible():
# -> 4385         ba = martist._get_tightbbox_for_layout_only(axis, renderer)
#    4386         if ba:
#    4387             bb.append(ba)
#
# File c:\python\Lib\site-packages\matplotlib\artist.py:1415, in _get_tightbbox_for_layout_only(obj, *args, **kwargs)
#    1409 """
#    1410 Matplotlib's `.Axes.get_tightbbox` and `.Axis.get_tightbbox` support a
#    1411 *for_layout_only* kwarg; this helper tries to use the kwarg but skips it
#    1412 when encountering third-party subclasses that do not support it.
#    1413 """
#    1414 try:
# -> 1415     return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#    1416 except TypeError:
#    1417     return obj.get_tightbbox(*args, **kwargs)
#
# File c:\python\Lib\site-packages\matplotlib\axis.py:1323, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1321 if renderer is None:
#    1322     renderer = self.figure._get_renderer()
# -> 1323 ticks_to_draw = self._update_ticks()
#    1325 self._update_label_position(renderer)
#    1327 # go back to just this axis's tick labels
#
# File c:\python\Lib\site-packages\matplotlib\axis.py:1270, in Axis._update_ticks(self)
#    1268     tick.set_label1(label)
#    1269     tick.set_label2(label)
# -> 1270 minor_locs = self.get_minorticklocs()
#    1271 minor_labels = self.minor.formatter.format_ticks(minor_locs)
#    1272 minor_ticks = self.get_minor_ticks(len(minor_locs))
#
# File c:\python\Lib\site-packages\matplotlib\axis.py:1491, in Axis.get_minorticklocs(self)
#    1489 minor_locs = np.asarray(self.minor.locator())
#    1490 if self.remove_overlapping_locs:
# -> 1491     major_locs = self.major.locator()
#    1492     transform = self._scale.get_transform()
#    1493     tr_minor_locs = transform.transform(minor_locs)
#
# File c:\python\Lib\site-packages\matplotlib\ticker.py:2136, in MaxNLocator.__call__(self)
#    2134 def __call__(self):
#    2135     vmin, vmax = self.axis.get_view_interval()
# -> 2136     return self.tick_values(vmin, vmax)
#
# File c:\python\Lib\site-packages\matplotlib\ticker.py:2144, in MaxNLocator.tick_values(self, vmin, vmax)
#    2141     vmin = -vmax
#    2142 vmin, vmax = mtransforms.nonsingular(
#    2143     vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2144 locs = self._raw_ticks(vmin, vmax)
#    2146 prune = self._prune
#    2147 if prune == 'lower':
#
# File c:\python\Lib\site-packages\matplotlib\ticker.py:2083, in MaxNLocator._raw_ticks(self, vmin, vmax)
#    2081 if self._nbins == 'auto':
#    2082     if self.axis is not None:
# -> 2083         nbins = np.clip(self.axis.get_tick_space(),
#    2084                         max(1, self._min_n_ticks - 1), 9)
#    2085     else:
#    2086         nbins = 9
#
# File c:\python\Lib\site-packages\matplotlib\axis.py:2475, in XAxis.get_tick_space(self)
#    2474 def get_tick_space(self):
# -> 2475     ends = mtransforms.Bbox.unit().transformed(
#    2476         self.axes.transAxes - self.figure.dpi_scale_trans)
#    2477     length = ends.width * 72
#    2478     # There is a heuristic here that the aspect ratio of tick text
#    2479     # is no more than 3:1
#
# File c:\python\Lib\site-packages\matplotlib\transforms.py:479, in BboxBase.transformed(self, transform)
#     475 """
#     476 Construct a `Bbox` by statically transforming this one by *transform*.
#     477 """
#     478 pts = self.get_points()
# --> 479 ll, ul, lr = transform.transform(np.array(
#     480     [pts[0], [pts[0, 0], pts[1, 1]], [pts[1, 0], pts[0, 1]]]))
#     481 return Bbox([ll, [lr[0], ul[1]]])
#
# File c:\python\Lib\site-packages\matplotlib\transforms.py:1498, in Transform.transform(self, values)
#    1495 values = values.reshape((-1, self.input_dims))
#    1497 # Transform the values
# -> 1498 res = self.transform_affine(self.transform_non_affine(values))
#    1500 # Convert the result back to the shape of the input values.
#    1501 if ndim == 0:
#
# File c:\python\Lib\site-packages\matplotlib\transforms.py:2423, in CompositeGenericTransform.transform_affine(self, points)
#    2421 def transform_affine(self, points):
#    2422     # docstring inherited
# -> 2423     return self.get_affine().transform(points)
#
# File c:\python\Lib\site-packages\matplotlib\transforms.py:2449, in CompositeGenericTransform.get_affine(self)
#    2447     return self._b.get_affine()
#    2448 else:
# -> 2449     return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2450                            self._a.get_affine().get_matrix()))
#
# File <__array_function__ internals>:180, in dot(*args, **kwargs)
#
# KeyboardInterrupt:
